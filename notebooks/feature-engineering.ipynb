# %%
import pandas as pd
df = pd.read_csv("../data/cleaned_personal_loan.csv")

# %%
X = df.drop('Personal.Loan', axis=1)
y = df['Personal.Loan']

print(X.shape)
print(y.shape)
# Out:
# (5000, 11)
# (5000,)

# %%
df.to_csv("featured_personal_loan.csv", index=False)

# %% [markdown]
# ## Feature Engineering
#
#     The dataset was already clean and well-structured with all features available in numerical format and directly relevant to the prediction task. Therefore, no additional feature engineering was performed. Only the input features (X) and target variable (y) were separated before model training.
